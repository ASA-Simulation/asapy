# %% [markdown]
# # ASAPY
# ### Asa Analysis
#
# #### Analysis.EDA
#
#     """
#     Perform exploratory data analysis (EDA) on a pandas DataFrame.
#
#     The function provides a summary of the DataFrame, showing class balance for categorical variables,
#     and displaying histograms and boxplots with outlier information for numerical variables. If desired,
#     the function can save these plots to a specified location.
#
#     Args:
#         df (pd.DataFrame): DataFrame to be analyzed.
#         save (bool, optional): Whether to save the plots. Defaults to False.
#         path (str, optional): Directory where the plots should be saved. If save is True, this parameter
#                                 must be provided. Defaults to None.
#         format (str, optional): The file format for saved plots. Acceptable formats include png, pdf, ps, eps and svg.
#                                 Defaults to 'png'.
#
#     Raises:
#         ValueError: If 'save' is set to True but 'path' is not specified.
#
#     Returns:
#         None
#     """

# %%
import asapy
from sklearn.datasets import load_diabetes
X, y  = load_diabetes(as_frame=True, return_X_y=True)

Analysis = asapy.Analysis

Analysis().eda(X)
# Out:
# Categorial Features:
#
#                 sex
# ------  -----------
# nan       0
# count   442
# unique    2
# top      -0.0446416
# freq    235
# Histograms:
# Numerical Features:
#
#                  age            bmi             bp            s1             s2             s3             s4             s5             s6
# -----  -------------  -------------  -------------  ------------  -------------  -------------  -------------  -------------  -------------
# nan      0              0              0              0             0              0              0              0              0
# count  442            442            442            442           442            442            442            442            442
# mean    -2.51182e-19   -2.24556e-16   -4.79757e-17   -1.3815e-17    3.91843e-17   -5.77718e-18   -9.04254e-18    9.29372e-17    1.13032e-17
# std      0.047619       0.047619       0.047619       0.047619      0.047619       0.047619       0.047619       0.047619       0.047619
# min     -0.107226      -0.0902753     -0.112399      -0.126781     -0.115613      -0.102307      -0.0763945     -0.126097      -0.137767
# 25%     -0.0372993     -0.0342291     -0.0366561     -0.0342478    -0.0303584     -0.0351172     -0.0394934     -0.0332456     -0.033179
# 50%      0.00538306    -0.00728377    -0.00567042    -0.00432087   -0.00381907    -0.00658447    -0.00259226    -0.00194717    -0.0010777
# 75%      0.0380759      0.031248       0.0356438      0.028358      0.0298444      0.0293115      0.0343089      0.0324323      0.0279171
# max      0.110727       0.170555       0.132044       0.153914      0.198788       0.181179       0.185234       0.133597       0.135612
#
# Correlation:
# Histograms and Boxplots:
# Outlier detection for variable 'age':
# 	Quantity: 0 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.15 or larger than 0.15 were considered outliers.
#
#
#
# Outlier detection for variable 'bmi':
# 	Quantity: 3 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.13 or larger than 0.13 were considered outliers.
#
#
#
# Outlier detection for variable 'bp':
# 	Quantity: 0 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.15 or larger than 0.14 were considered outliers.
#
#
#
# Outlier detection for variable 's1':
# 	Quantity: 8 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.13 or larger than 0.12 were considered outliers.
#
#
#
# Outlier detection for variable 's2':
# 	Quantity: 7 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.12 or larger than 0.12 were considered outliers.
#
#
#
# Outlier detection for variable 's3':
# 	Quantity: 7 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.13 or larger than 0.13 were considered outliers.
#
#
#
# Outlier detection for variable 's4':
# 	Quantity: 2 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.15 or larger than 0.15 were considered outliers.
#
#
#
# Outlier detection for variable 's5':
# 	Quantity: 4 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.13 or larger than 0.13 were considered outliers.
#
#
#
# Outlier detection for variable 's6':
# 	Quantity: 9 of 442.
# 	Method: Interquartile Range (IQR).
# 	Criteria: Values smaller than -0.12 or larger than 0.12 were considered outliers.
